# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Matplotlib

# %%
x = [1, 2, 3, 4]
y = [3, 6, 8, 12]
plt.plot(x,y)
plt.title('notre premier schema')
plt.xlabel('axe des x')
plt.ylabel('axe des y')
plt.show()

# %%
# axis plutot axes
x = [1, 2, 3, 4]
y = [3, 6, 8, 12]
fig, ax = plt.subplots(figsize=(16, 8), nrows=1, ncols=2)
print(ax)
ax[0].plot(x,y)
ax[0].set_xlabel("1er plot")
ax[1].plot(np.array(x)+1, y)
ax[1].set_yticks([0, 5, 8, 12])

# %%
dir(ax[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_axis_map',
#  '_get_clipping_extent_bbox',
#  '_get_lines',
# ...

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.50       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %% [markdown]
# # Pandas

# %%
from sklearn.datasets import load_iris
data = load_iris()
iris=pd.DataFrame(data=data.data,columns=data.feature_names)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris.plot(kind='scatter', x='petal length (cm)', y='petal width (cm)')

# %%
iris['petal width (cm)'].plot( kind='hist')

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
data = '/gdrive/My Drive/DataKev/data/'

# %%
import os
os.listdir(data)
# Out:
# ['Visualisation de données avec Matplotlib et seaborn.ipynb',
#  'movie.csv',
#  'train.csv',
#  'Analyse Titanic.ipynb',
#  'top10s.csv',
#  'TD - Titanic.ipynb',
#  'TD - Spotify.ipynb',
#  'Automobile_data.csv',
#  'TimeSeriesAnalysis.ipynb',
#  'Data Wrangling.ipynb',
#  'Bootcamp Recap.gdoc']

# %%
lien = 'https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv'

# %%
titanic = pd.read_csv(lien)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic.Sex.value_counts().plot(kind='bar')

# %%
dir(pd.DataFrame.plot)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_all_kinds',
#  '_common_kinds',
#  '_constructor',
#  '_dataframe_kinds',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_call_args',
#  '_kind_aliases',
#  '_reset_cache',
#  '_series_kinds',
#  'area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
titanic.Sex.value_counts().plot(kind='pie')

# %% [markdown]
# # Guide de visualisation

# %% [markdown]
# * une variable numerique : histogramme, boxplot, kernel density plot
# * une variable catégorielle: piechart, barchat
#
# * 2 variables numériques : scatter plot, heatmap
# * 2 variables catégorielles: barchat

# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Box plot (analyse univarié numérique)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
sns.boxplot(data=titanic, x="Age")

# %%
sns.boxplot(data=titanic, y="Age")

# %%
sns.boxplot(titanic.Age)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Kernel density plot (variable numérique)

# %%
sns.kdeplot(titanic.Age)

# %% [markdown]
# ## Violin plot (x=category, y=numerique)

# %%
sns.violinplot(x="Survived", y="Age", data=titanic)

# %% [markdown]
# ## Countplot (une variable catégorielle)

# %%
# tidy data
sns.countplot(titanic['Sex'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(titanic['Survived'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Heatmap (plusieurs variables numériques)

# %%
sns.heatmap(titanic.corr(), annot=True, cmap='YlGnBu')

# %%
sns.heatmap(titanic.corr(method='spearman'), annot=True, cmap='YlGnBu')

# %%
sns.heatmap(titanic.corr()[['Survived', 'Age']], annot=True, cmap='YlGnBu')

# %%
titanic['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(titanic['Survived'])
# Out:
# pandas.core.series.Series

# %%
type(titanic[['Survived']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Facetgrid (2 variable categorie et 1 numérique)

# %%
cond = (titanic.Sex=='male') & (titanic.Survived==0)
titanic[cond]['Age'].hist()

# %%
grid = sns.FacetGrid(titanic, col="Sex", row="Survived")
grid.map(plt.hist, 'Age')

# %%
titanic.Pclass.isnull().sum()
# Out:
# 0

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Regplot (scatter plot du riche)

# %%
sns.regplot(data=titanic, x='Age', y='Fare')

# %% [markdown]
# ## lmplot (facetgrid + regplot) 2 variables category 2 variable numérique

# %%
titanic.Fare.hist()

# %%
sns.lmplot(data=titanic, x='Age', y='Fare', row='Survived', col='Sex')

# %% [markdown]
# ## Strip plot : Scatter mais pour visualiser une varible numérique et une variable de catégorie

# %%
sns.stripplot(data=titanic, x="Survived", y='Age')

# %% [markdown]
# ## swarm plot : strip plot mais avec la distribution

# %%
sns.swarmplot(data=titanic, x="Survived", y='Age')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Catplot strip plot + facet grid

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
#
# [2 rows x 12 columns]

# %%
sns.catplot(data=titanic, x="Survived", y="Age", col="Sex", row="Pclass")

# %%
sns.catplot(data=titanic, x="Survived", y="Age", col="Sex", row="Pclass", kind='violin')

# %%
sns.catplot(data=titanic, x="Survived", y="Age", col="Sex", row="Pclass", kind='swarm')

# %% [markdown]
# ## pairplot : matrice de visualisation

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic['Survived']=titanic['Survived'].astype('category')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: category(1), float64(2), int64(4), object(5)
# memory usage: 77.7+ KB

# %%
sns.pairplot(data=titanic)

# %%
sns.pairplot(data=titanic, hue="Survived")

# %% [markdown]
# [Documentation de Seaborn](https://seaborn.pydata.org/tutorial.html)
